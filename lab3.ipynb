# %% [markdown]
# # **Laboratory exercise 3**

# %%
# !pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo

dataset = fetch_ucirepo(id=342).data.original

# %% [markdown]
# Preprocess the data

# %%
dataset.head()
# Out:
#   MouseID  DYRK1A_N   ITSN1_N    BDNF_N     NR1_N  ...    CaNA_N  Genotype  Treatment  Behavior   class
# 0   309_1  0.503644  0.747193  0.430175  2.816329  ...  1.675652   Control  Memantine       C/S  c-CS-m
# 1   309_2  0.514617  0.689064  0.411770  2.789514  ...  1.743610   Control  Memantine       C/S  c-CS-m
# 2   309_3  0.509183  0.730247  0.418309  2.687201  ...  1.926427   Control  Memantine       C/S  c-CS-m
# 3   309_4  0.442107  0.617076  0.358626  2.466947  ...  1.700563   Control  Memantine       C/S  c-CS-m
# 4   309_5  0.434940  0.617430  0.358802  2.365785  ...  1.839730   Control  Memantine       C/S  c-CS-m
#
# [5 rows x 82 columns]

# %%
dataset = dataset.drop(['MouseID', 'Genotype', 'Treatment', 'Behavior','class'], axis=1)
dataset = dataset.dropna()
dataset.head()
# Out:
#     DYRK1A_N   ITSN1_N    BDNF_N     NR1_N  ...  H3AcK18_N    EGR1_N  H3MeK4_N    CaNA_N
# 75  0.649781  0.828696  0.405862  2.921435  ...   0.125152  0.146865  0.143517  1.627181
# 76  0.616481  0.841974  0.388584  2.862575  ...   0.112857  0.161132  0.145719  1.562096
# 77  0.637424  0.852882  0.400561  2.968155  ...   0.116433  0.160594  0.142879  1.571868
# 78  0.576815  0.755390  0.348346  2.624901  ...   0.102831  0.144238  0.141681  1.646608
# 79  0.542545  0.757917  0.350051  2.634509  ...   0.110614  0.155667  0.146408  1.607631
#
# [5 rows x 77 columns]

# %% [markdown]
# Principal component analysis in 3 dimensions

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=3)
pca_data = pca.fit_transform(dataset)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(pca_data[:, 0], pca_data[:, 1], pca_data[:, 2], c='blue', edgecolor='k', s=40)
ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('Principal Component 3')
ax.set_title('PCA - 3D Visualization')
plt.show()

# %% [markdown]
# ## **K means clustering**

# %% [markdown]
# Find the best K (an elbow in the WCV, with the BCV remaining high)

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="sklearn")

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from scipy.spatial import distance

fig1 = plt.figure(figsize=(9, 9))
wcv = {}
bcv = {}
X = dataset

for k in range(1, 20):
    kmeans = KMeans(n_clusters=k,max_iter=1000).fit(X)
    wcv[k] = kmeans.inertia_
    centers = kmeans.cluster_centers_
    BCV = 0
    for i in range(len(centers)):
        for j in range(len(centers)):
            BCV += distance.euclidean(centers[i], centers[j])**2
    if(k==1):
        bcv[1] = 0
    else:
        bcv[k] = BCV/(k*(k-1))*100
plt.plot(list(wcv.keys()), list(wcv.values()), label="Within Cluster Distance (WCV)")
plt.plot(list(bcv.keys()), list(bcv.values()), label="Between Cluster Distance (BCV)")
plt.xlabel("Number of clusters K")
plt.ylabel("Inertia")
plt.legend()
plt.show()

# %% [markdown]
# According to these results - I am going to try with 4, 5 and 6 clusters.

# %%
n_clusters = [3,4,5]
evaluators = []
for n in n_clusters:
  evaluators.append(KMeans(n_clusters=n, random_state=10, n_init='auto').fit(dataset))

# %% [markdown]
# ### **Visualization**

# %%
from sklearn.manifold import TSNE

for i, evaluator in enumerate(evaluators):
  tsne = TSNE(n_components=3)
  tsne_data = tsne.fit_transform(dataset)

  fig = plt.figure()
  ax = fig.add_subplot(111, projection='3d')
  ax.scatter(tsne_data[:, 0], tsne_data[:, 1], tsne_data[:, 2], c=evaluator.labels_)
  ax.set_xlabel('Feature 1')
  ax.set_ylabel('Feature 2')
  ax.set_zlabel('Feature 3')
  plt.title(f'K-means PCA visualization with {n_clusters[i % len(n_clusters)]} clusters')
  plt.show()

# %% [markdown]
# ## **Gaussian mixture models**

# %%
from sklearn.mixture import GaussianMixture

evaluators = []
for n in n_clusters:
    gmm = GaussianMixture(n_components=n, random_state=10)
    gmm.fit(dataset)
    gmm_labels = gmm.predict(dataset)
    evaluators.append(gmm_labels)

# %% [markdown]
# ### **Visualization**

# %%
for i, evaluator in enumerate(evaluators):
    tsne = TSNE(n_components=3, random_state=42)
    tsne_data = tsne.fit_transform(dataset)

    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    labels = evaluator

    ax.scatter(tsne_data[:, 0], tsne_data[:, 1], tsne_data[:, 2], c=labels)
    ax.set_xlabel('Feature 1')
    ax.set_ylabel('Feature 2')
    ax.set_zlabel('Feature 3')
    plt.title(f'GMM visualization with {n_clusters[i % len(n_clusters)]} clusters')
    plt.show()

# %% [markdown]
# The two models give the same results
